# %% [markdown]
# ## Rich output
#
# The object below advertises several representations. The table is the
# same data as $\mathbf{X} \in \mathbb{R}^{n \times p}$ above.

# %%
sales.groupby("region").total.sum().reset_index().head(1)
# Out:
#   region   total
# 0  north  1204.5

# %%
from IPython.display import JSON

JSON(manifest, root="manifest")

# %%
from IPython.display import HTML, Latex

display(HTML("<b>All checks passed.</b>"))
display(Latex(r"$\sum_{i=1}^{n} x_i$"))
# Out:
# <b>All checks passed.</b>
# $\sum_{i=1}^{n} x_i$
