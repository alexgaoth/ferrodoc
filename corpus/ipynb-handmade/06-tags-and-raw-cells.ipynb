# %% [raw]
# <style>
# .dataframe td { text-align: right; }
# </style>

# %% [markdown]
# # Appendix
#
# Everything below is generated. Do not edit by hand.

# %%
print("regenerating appendix")
regenerate()
# Out:
# regenerating appendix

# %% [raw]
# This raw cell has no format at all, so nothing but a notebook
# knows what to do with it.

# %% [raw]
# .. note::
#
#    Written for Sphinx, carried through untouched.

# %%
finish()
# Out:
# 'appendix written'
