# %%
6 * 7
# Out:
# 42

# %%
import sys
print("starting")
fetch()
print("done")
sorted(labels)
# Out:
# starting
# /opt/conda/lib/python3.11/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+
#   warnings.warn(
# done
# ['a', 'b', 'c']

# %%
sales.total.describe()
# Out:
# count    1042.000000
# mean       27.418000
# std        11.902000
# min         0.000000
# max       310.500000
# Name: total, dtype: float64

# %%
# not run yet
publish(report)
