# %% [markdown]
# # Rapport trimestriel
#
# ![le logo](attachment:logo.png)
#
# Données pour la région **Île-de-France** — 中文说明如下 — «citation».
#
# Naïve résumé: 25 °C, 3 µm, ½ de l'échantillon.

# %%
for key, value in résumé.items():
    print(f"{key}: {value}")
# Out:
# région: Île-de-France
# température: 25 °C
# échantillon: 50 %
# 説明: 完了

# %%
verify(sales, verbose=True)
# Out:
# row 000 ................................ ok
# row 001 ................................ ok
# row 002 ................................ ok
# row 003 ................................ ok
# row 004 ................................ ok
# row 005 ................................ ok
# row 006 ................................ ok
# row 007 ................................ ok
# row 008 ................................ ok
# row 009 ................................ ok
# row 010 ................................ ok
# row 011 ................................ ok
# row 012 ................................ ok
# row 013 ................................ ok
# row 014 ................................ ok
# row 015 ................................ ok
# row 016 ................................ ok
# row 017 ................................ ok
# row 018 ................................ ok
# row 019 ................................ ok
# row 020 ................................ ok
# ...
