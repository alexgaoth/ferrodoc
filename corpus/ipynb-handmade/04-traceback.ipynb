# %% [markdown]
# ### What happens on a bad postcode
#
# Left in deliberately: the traceback is the documentation.

# %%
parse_postcode("SW1A")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 parse_postcode("SW1A")
#
# File ~/work/geo.py:18, in parse_postcode(text)
#      17 if not OUTCODE.match(text):
# ---> 18     raise ValueError(f"invalid postcode: {text!r}")
#
# ValueError: invalid postcode: 'SW1A'

# %%
sales["refund"].sum()
# Out:
# Traceback (most recent call last):
#   File "<stdin>", line 1, in <module>
# KeyError: 'refund'
# column 'refund' is optional; continuing
