# %% [markdown]
# ## Revenue by month
#
# The chart below is the whole point of the notebook. It plots
# $R_m = \sum_{o \in m} \mathrm{total}_o$ for each month $m$.

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
ax.plot(months, revenue)
plt.show()

# %%
print("saved figure to build/revenue.png")
thumbnail(fig)
# Out:
# saved figure to build/revenue.png
